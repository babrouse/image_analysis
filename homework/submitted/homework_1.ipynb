# %% [markdown]
# Import packages and open the images

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
image_A_png = plt.imread('images/AuLait_gray.png')
image_A_tif = plt.imread('images/AuLait_gray.tif')

plt.imshow(image_A_png, 'gray')

print(image_A_png)
# Out:
# [[0.27450982 0.2901961  0.30588236 ... 0.27058825 0.27058825 0.27450982]
#  [0.27450982 0.2901961  0.30588236 ... 0.27450982 0.27450982 0.27058825]
#  [0.27058825 0.28627452 0.3019608  ... 0.28235295 0.2784314  0.27450982]
#  ...
#  [0.38039216 0.38039216 0.3764706  ... 0.58431375 0.58431375 0.5764706 ]
#  [0.3882353  0.38431373 0.38039216 ... 0.58431375 0.58431375 0.57254905]
#  [0.3882353  0.38431373 0.3764706  ... 0.5803922  0.5803922  0.5764706 ]]
